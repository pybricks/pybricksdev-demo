# %%
ICONS_INVERTED = {
    "UP" : (
        ("⬜⬜⬛⬜⬜",
         "⬜⬛⬛⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬛⬛⬜",
         "⬜⬛⬛⬛⬜")
    ),
    "DOWN" : (
        ("⬜⬛⬛⬛⬜",
         "⬜⬛⬛⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬛⬛⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "LEFT" : (
        ("⬜⬜⬛⬜⬜",
         "⬜⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬛⬛⬛",
         "⬜⬜⬛⬜⬜")
    ),
    "RIGHT" : (
        ("⬜⬜⬛⬜⬜",
         "⬛⬛⬛⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "ARROW_RIGHT_UP" : (
        ("⬜⬜⬛⬛⬛",
         "⬜⬜⬜⬛⬛",
         "⬜⬜⬛⬜⬛",
         "⬜⬛⬜⬜⬜",
         "⬛⬜⬜⬜⬜")
    ),
    "ARROW_RIGHT_DOWN" : (
        ("⬛⬜⬜⬜⬜",
         "⬜⬛⬜⬜⬜",
         "⬜⬜⬛⬜⬛",
         "⬜⬜⬜⬛⬛",
         "⬜⬜⬛⬛⬛")
    ),
    "ARROW_LEFT_UP" : (
        ("⬛⬛⬛⬜⬜",
         "⬛⬛⬜⬜⬜",
         "⬛⬜⬛⬜⬜",
         "⬜⬜⬜⬛⬜",
         "⬜⬜⬜⬜⬛")
    ),
    "ARROW_LEFT_DOWN" : (
        ("⬜⬜⬜⬜⬛",
         "⬜⬜⬜⬛⬜",
         "⬛⬜⬛⬜⬜",
         "⬛⬛⬜⬜⬜",
         "⬛⬛⬛⬜⬜")
    ),
    "ARROW_UP" : (
        ("⬜⬜⬛⬜⬜",
         "⬜⬛⬛⬛⬜",
         "⬛⬜⬛⬜⬛",
         "⬜⬜⬛⬜⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "ARROW_DOWN" : (
        ("⬜⬜⬛⬜⬜",
         "⬜⬜⬛⬜⬜",
         "⬛⬜⬛⬜⬛",
         "⬜⬛⬛⬛⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "ARROW_LEFT" : (
        ("⬜⬜⬛⬜⬜",
         "⬜⬛⬜⬜⬜",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬜⬜⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "ARROW_RIGHT" : (
        ("⬜⬜⬛⬜⬜",
         "⬜⬜⬜⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬜⬜⬜⬛⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "HAPPY" : (
        ("⬛⬛⬜⬛⬛",
         "⬛⬛⬜⬛⬛",
         "⬜⬜⬜⬜⬜",
         "⬛⬜⬜⬜⬛",
         "⬜⬛⬛⬛⬜")
    ),
    "SAD" : (
        ("⬛⬛⬜⬛⬛",
         "⬛⬛⬜⬛⬛",
         "⬜⬜⬜⬜⬜",
         "⬜⬛⬛⬛⬜",
         "⬛⬜⬜⬜⬛")
    ),
    "EYE_LEFT" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬛⬛⬜⬜⬜",
         "⬛⬛⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_RIGHT" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬛⬛",
         "⬜⬜⬜⬛⬛",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_LEFT_BLINK" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬛⬛⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_RIGHT_BLINK" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬛⬛",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_RIGHT_BROW" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬛⬛",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_LEFT_BROW" : (
        ("⬜⬜⬜⬜⬜",
         "⬛⬛⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_LEFT_BROW_UP" : (
        ("⬛⬛⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "EYE_RIGHT_BROW_UP" : (
        ("⬜⬜⬜⬛⬛",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "HEART" : (
        ("⬜⬛⬜⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬛⬛⬜",
         "⬜⬜⬛⬜⬜")
    ),
    "PAUSE" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬛⬜⬛⬜",
         "⬜⬛⬜⬛⬜",
         "⬜⬛⬜⬛⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "EMPTY" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "FULL" : (
        ("⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛")
    ),
    "SQUARE" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬛⬛⬛⬜",
         "⬜⬛⬛⬛⬜",
         "⬜⬛⬛⬛⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "TRIANGLE_RIGHT" : (
        ("⬜⬛⬜⬜⬜",
         "⬜⬛⬛⬜⬜",
         "⬜⬛⬛⬛⬜",
         "⬜⬛⬛⬜⬜",
         "⬜⬛⬜⬜⬜")
    ),
    "TRIANGLE_LEFT" : (
        ("⬜⬜⬜⬛⬜",
         "⬜⬜⬛⬛⬜",
         "⬜⬛⬛⬛⬜",
         "⬜⬜⬛⬛⬜",
         "⬜⬜⬜⬛⬜")
    ),
    "TRIANGLE_UP" : (
        ("⬜⬜⬜⬜⬜",
         "⬜⬜⬛⬜⬜",
         "⬜⬛⬛⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬜⬜⬜⬜⬜")
    ),
    "TRIANGLE_DOWN" : (
        ("⬜⬜⬜⬜⬜",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬛⬛⬜",
         "⬜⬜⬛⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "CIRCLE" : (
        ("⬜⬛⬛⬛⬜",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬛⬛⬛⬛⬛",
         "⬜⬛⬛⬛⬜")
    ),
    "CLOCKWISE" : (
        ("⬛⬛⬛⬛⬜",
         "⬛⬜⬜⬛⬜",
         "⬛⬜⬜⬛⬜",
         "⬛⬜⬛⬛⬛",
         "⬜⬜⬜⬛⬜")
    ),
    "COUNTERCLOCKWISE" : (
        ("⬜⬛⬛⬛⬛",
         "⬜⬛⬜⬜⬛",
         "⬜⬛⬜⬜⬛",
         "⬛⬛⬛⬜⬛",
         "⬜⬛⬜⬜⬜")
    ),
    "TRUE" : (
        ("⬜⬜⬜⬜⬛",
         "⬜⬜⬜⬛⬜",
         "⬛⬜⬛⬜⬜",
         "⬜⬛⬜⬜⬜",
         "⬜⬜⬜⬜⬜")
    ),
    "FALSE" : (
        ("⬛⬜⬜⬜⬛",
         "⬜⬛⬜⬛⬜",
         "⬜⬜⬛⬜⬜",
         "⬜⬛⬜⬛⬜",
         "⬛⬜⬜⬜⬛")
    ),
}

# SIZE = 5
# for r in range(SIZE):
#     for c in range(SIZE):
#         name = "P{0}{1}".format(r, c)
#         icon = ["".join(["⬛" if (i, j) == (r, c) else "⬜" for j in range(SIZE)]) for i in range(SIZE)]
#         ICONS_INVERTED[name] = icon

# %%
for name, icon_inverted in ICONS_INVERTED.items():
    
    print("        case MP_QSTR_{0}:".format(name))
    for i, row_inverted in enumerate(icon_inverted):
        # Invert the row
        
        ret = "return" if i == 0 else "      "
        end = ";  " if i + 1 == len(icon_inverted) else " | " 
        
        pixels = row_inverted.replace('⬜', 'W').replace('⬛', '⬜').replace('W', '⬛')
        bits = "".join([(str(0) if p == '⬛' else str(1)) for p in pixels])
        
        line = " " * 12 + "{ret} (0b{bits} << {shift:02d}){end} // {pixels}".format(
            ret=ret, pixels=pixels, end=end, bits=bits, shift=(4-i)*5
        )
        
        print(line)
